# %%
# criar a venv 
# pip install openai 
# pip install requests 
# pip install langgraph 
# pip install chromadb 
# pip install streamlit 
# pip install pypdf 
# pip install sentence-transformers
# ollama run llama3

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio"
)

resp = client.chat.completions.create(
    model="meta-llama-3-8b-instruct",
    messages=[
        {"role": "user", "content": "Olá! Você está funcionando?"}
    ]
)

print(resp.choices[0].message.content)
# Out:
# Olá! Sim, estou funcionando normalmente. Estou aqui para ajudar com suas perguntas e responder a suas necessidades. Qual é o seu problema ou questão que você gostaria de discutir?
